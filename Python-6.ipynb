# %%
#Liste (List) Veri Yapıları
#Köşeli parantez içine yazılır.
#İndisleri sıfırdan başlar
#Elemanları değiştirilebilir.(mutable)
#Dilimlenebilir.(sliceable)
#İçiçe geçebilir.(nestable)
#Sıralı dizilimlerdir.(sequence)
#Bir list nesnesi her tür veriyi saklayabilir.

# %%
l=[1,2,3,4,5]
l[0]
# Out:
# 1

# %%
birinci, *digerleri= sorted([3,4,5,10,98,54,45])
birinci,digerleri
# Out:
# (3, [4, 5, 10, 45, 54, 98])

# %%
#LİST METODLARI
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
L=[1,5,9,4,6,8,7]
L.append(9) #Elemanı listenin sonuna ekler
L
# Out:
# [1, 5, 9, 4, 6, 8, 7, 9]

# %%
#range() fonksiyonu ile liste oluşturmak

range(10)
# Out:
# range(0, 10)

# %%
range(2,10,3)
# Out:
# range(2, 10, 3)

# %%
# pop() ve append() -----> LIFO
# pop()  ve insert() --------> FIFO

# %%
kareler =[]
for a in range(10):
    kareler.append(a**2)
kareler
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
L= range(10,60,10)
list(L)
# Out:
# [10, 20, 30, 40, 50]
