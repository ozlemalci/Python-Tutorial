# %%
# Demet(Tuple) Veri Yapıları
# Parantez içine yazılır, zorunlu değil.
# Elemanları değiştirilemez.(immutable)
# Dilimlenebilir.(sliceable)
# İç içe geçebilir.(nestable)
# Bir demet her türlü veri ve veri yapısını kapsayabilir.

# %%
# Tuple Fonksiyonları

cmp(t1,t2)
len(t)
max(t)
min(t)
t1=sorted(t)
sum(t)
tuple(liste)

# %%
# Packing and Unpacking

p= (1,2,"özlem",3) # Packing
(a,b,c,d)=p  #Unpacking
p
# Out:
# (1, 2, 'özlem', 3)

# %%
#Fonksiyonlar tuple şeklinde değer döndürebilir.

def fonksiyon1(c):
    a=11
    b=73
    if a<c:
        return(a,b)
    else:
        return(c,b)
