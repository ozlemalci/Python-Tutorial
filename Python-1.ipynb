# %%
# !pip install python== 3.6.3
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ERROR: Could not find a version that satisfies the requirement python== (from versions: none)
# ERROR: No matching distribution found for python==
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
print("Merhaba Dünya!")
# Out:
# Merhaba Dünya!

# %%
dir() #Sabit ve Değişkenlerin Listesi
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_deepnote_add_formatters',
#  '_deepnote_execute_sql',
#  '_deepnote_get_var_list',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'python_version',
#  'quit',
#  'setNotebookPath',
#  'sys']

# %%
help(dir)

# %%
sayi=5
type(sayi)
# Out:
# int

# %%
#Herhangi bir değişken,sabit,metot veya fonksiyonu 
#isimlendirirken veya var olan bir tanımlayıcı hakkında 
#bilgi edinmek için help(),type(),dir() kullanılır.

# %%
#Sınıf isimleri = KelimelerinİlkHarfleriBüyük
#Metod,fonksiyon ve değişkenler =alt_cizgili_kucuk_harf
#Özel metod ve özellikler = __cift_alt_cizgi_ile_baslar
#Protected metodlar= _tek_alt_cizgi_ile_baslar
