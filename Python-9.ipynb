# %%
# SÖZLÜK(DICT) VERİ YAPILARI

# Süslü parantezler arasına yazılır.
# Sırasız anahtar:değer çiftleri kolleksiyonudur.
# Eleman erişimi için anahtarlar kullanılır.
# Anahtar değerleri unique
# Elemanları değişebilir.
# Ekleme,silme,okuma gibi işlemleri vardır.

# %%
notlar= {"Ali" : 88 , "Özlem": 95, "Batuhan": 96}
type(notlar),len(notlar)
notlar["Batuhan"]
# Out:
# 96
