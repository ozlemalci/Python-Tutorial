# %%
x+y 
x-y
x*y
x/y
x//y # x sayısının y sayısına bölünmesiyle elde edilen tam kısmın bulunması
x%y # x sayısının y sayısına bölünmesiyle elde edilen kalan kısmın bulunması
x**y # x üssü y
-x

abs(x) #mutlak değer x
divmod(x,y) # x'in y ile bölümünden elde edilen kalan ve tam kısımlarının iki tam sayıdan 
#oluşan tuple halinde döndürülmesi
pow(x,y) # x üssü y
pow(x,y,z) #pow(x,y)%z
round(x,n) #x'in n haneye yuvarlanması
bin(i) #on tabanlı sayının iki tabanına dönüştürülmüş hali
hex(i) #on tabanlı sayının onaltılık tabana dönüştülmüş hali
int(x) # x nesnesinin tam sayıya dönüştürülmesi
oct(i) #on tabanlı sayının sekiz tabanına dönüştürülmesi
str(i) #on tabanlı sayının stringe dönüştürülmesi

# %%
s[i] ='string yapisi'
liste1=[1,2,3]
demet1=(123,'a') #tuple yapısı
kume1={0,1,2}
